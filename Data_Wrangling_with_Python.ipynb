# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# <pre>
# <b>Data Wrangling</b> is important and this is because most times data dosen't come in the format that is useful for us or in a pattern that can be understood by our model.So we have to set our data in a format that is readable by our model for optimal interpretation.
# </pre>

# %% [markdown]
# We would be making use of the pandas libray which is a library in the Python Data Science package that helps us to analyse dataframe.

# %% [markdown]
# The dataset we imported does not have headers so we have to use a <b><i>python list</i></b> that contains the name of the <b>headers</b>

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
#we start by importing  pandas;
# our dataset is named automobiles.csv. This is the data we would be working on to change its format.
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Automobile.csv')
df.shape
# Out:
# (204, 27)

# %%
#we can see that we get the csv in a data frame but there is one unwanted column called Unnamed
df
# Out:
#      Unnamed: 0  3    ?  alfa-romero     gas    std   two  convertible  rwd  \
# 0             0  3    ?  alfa-romero     gas    std   two  convertible  rwd
# 1             1  1    ?  alfa-romero     gas    std   two    hatchback  rwd
# 2             2  2  164         audi     gas    std  four        sedan  fwd
# 3             3  2  164         audi     gas    std  four        sedan  4wd
# 4             4  2    ?         audi     gas    std   two        sedan  fwd
# ..          ... ..  ...          ...     ...    ...   ...          ...  ...
# 199         199 -1   95        volvo     gas    std  four        sedan  rwd
# 200         200 -1   95        volvo     gas  turbo  four        sedan  rwd
# 201         201 -1   95        volvo     gas    std  four        sedan  rwd
# 202         202 -1   95        volvo  diesel  turbo  four        sedan  rwd
# 203         203 -1   95        volvo     gas  turbo  four        sedan  rwd
#
# ...

# %%
#To remove that unwanted column we call the csv file this way:
df=pd.read_csv('Automobile.csv')
df.head()
df.shape
# Out:
# (204, 27)

# %%
df=pd.read_csv('Automobile.csv',index_col=0)

# %% [markdown]
# The dataset we imported does not have properly named descripitive headers so we have to use a <b><i>python list</i></b> that contains the name of the <b>headers</b>

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns=headers
#TO examine our dataframe lets call .head()
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      164
# 3      164
# 4      NaN
#       ...
# 199     95
# 200     95
# 201     95
# 202     95
# 203     95
# Name: normalized-losses, Length: 204, dtype: object

# %% [markdown]
# <pre>
#     We can see that some rows in our datasets contain ? these are missing values. It is important to note that for our model to able to perform optimally it needs every piece of data it can get in the right format.So how do we deal with missing values
# </pre>
#
# <ol>
# <li>identify missing values</li>
# <li>Deal with the missing value</li>
# <li>Correct the data format</li>
# </ol>

# %% [markdown]
# <h2 id="identify_handle_missing_values">Identify and handle missing values</h2>
#
#
# <h3 id="identify_missing_values">Identify missing values</h3>
# <h4>Convert "?" to NaN</h4>
# In the car dataset, missing data comes with the question mark "?".
# We replace "?" with NaN (Not a Number), which is Python's default missing value marker, for reasons of computational speed and convenience. Here we use the function:
#  <pre>.replace(A, B, inplace = True) </pre>
# to replace A by B

# %%
df.replace('?',np.nan,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# <p> Converting ? to nan helps us to be able to properly identify rows in that columns as missing values and thus help us to effectively handle them</p>

# %% [markdown]
# <h2> Evaluating for missing Data</h2>
# <p> we can now evaluate for missing data properly by easily calling on</p>
# <pre>
# 1) .isnull()
# 2) .notnull()
# </pre>
# <p> They return boolean values i.e True and False for rows depending if they meet the criteria. For example .isnull() will return a True value for rows that contain a missing value </p>

# %%
missing_data=df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %% [markdown]
# <p> Using the above variable we can determine the columns that have missing values and the number of mising values</p>

# %%
for columns in missing_data.columns.values.tolist():
    print(columns)
    print(missing_data[columns].value_counts())
    print(" ")
# Out:
# symboling
# False    204
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      40
# Name: normalized-losses, dtype: int64
#
# make
# False    204
# Name: make, dtype: int64
#
# fuel-type
# False    204
# Name: fuel-type, dtype: int64
#
# aspiration
# False    204
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    202
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    204
# Name: body-style, dtype: int64
#
# drive-wheels
# False    204
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    204
# Name: engine-location, dtype: int64
#
# wheel-base
# False    204
# Name: wheel-base, dtype: int64
#
# length
# False    204
# Name: length, dtype: int64
#
# width
# False    204
# Name: width, dtype: int64
#
# height
# False    204
# Name: height, dtype: int64
#
# curb-weight
# False    204
# Name: curb-weight, dtype: int64
#
# engine-type
# False    204
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty. In our dataset, none of the columns are empty enough to drop entirely.
# We have some freedom in choosing which method to replace data; however, some methods may seem more reasonable than others. We will apply each method to many different columns:
#
# <b>Replace by mean:</b>
# <ul>
#     <li>"normalized-losses": 40 missing data, replace them with mean</li>
#     <li>"stroke": 4 missing data, replace them with mean</li>
#     <li>"bore": 4 missing data, replace them with mean</li>
#     <li>"horsepower": 2 missing data, replace them with mean</li>
#     <li>"peak-rpm": 2 missing data, replace them with mean</li>
# </ul>
#
# <b>Replace by frequency:</b>
# <ul>
#     <li>"num-of-doors": 2 missing data, replace them with "four".
#         <ul>
#             <li>Reason: 84% sedans is four doors. Since four doors is most frequent, it is most likely to occur</li>
#         </ul>
#     </li>
# </ul>
#
# <b>Drop the whole row:</b>
# <ul>
#     <li>"price": 4 missing data, simply delete the whole row
#         <ul>
#             <li>Reason: price is what we want to predict. Any data entry without price data cannot be used for prediction; therefore any row now without price data is not useful to us</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h4> fill in the empty values with the mean value  using .fillna</h4>

# %%
df.fillna({'normalized-losses':df['normalized-losses'].astype(float).mean(),
          'stroke':df['stroke'].astype(float).mean(),'horsepower':df['horsepower'].astype(float).mean(),'bore':df.bore.astype(float).mean(),'peak-rpm':df['peak-rpm'].astype(float).mean()},inplace=True)

# %% [markdown]
# <p>you can also assign the mean value to the dataframe by creating a variable that holds the value of the mean</p>
# <p>I will give an example with the <b>normlalized-losses</b> column</p>
# <pre>average_value_norm=df['normalized-losses'].astype(float).mean()then we use the <b>.replace()</b> method:
# df['normalized.losses'].replace([np.nan,average_value_norm],inplace=True)
# </pre>

# %% [markdown]
# <p> The .value_counts() gives us the values present in a column and thus we can call upon it and the value .idxmax() to give us the highest occuring values</p>

# %%
doors_mode=df['num-of-doors'].value_counts().idxmax()

# %%
df['num-of-doors'].replace(np.nan,doors_mode,inplace=True)

# %%
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)

# %%
df['price'].isnull().any()
# Out:
# False

# %% [markdown]
# <h4>Putting the data in the correct format </h4>
# <p> After making sure we do not have missing values one more important step to take is to ensure that we want our data to be in the correct format. i.e We want numeric data to have a data type of int or float. While categorical variables will have the object data type. To confirm what data type our value are in we can run the .info() or .dtypes  We have to convert data types into a proper format for each column using the "astype()" method.

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# #### Converting data formats to the correct format

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %% [markdown]
# <h2 id="data_standardization">Data Standardization</h2>
# <p>
# Data is usually collected from different agencies with different formats.
# (Data Standardization is also a term for a particular type of data normalization, where we subtract the mean and divide by the standard deviation)
# </p>
#
# <b>What is Standardization?</b>
# <p>Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.
# </p>
#
# <b>Example</b>
# <p>Transform mpg to L/100km:</p>
# <p>In our dataset, the fuel consumption columns "city-mpg" and "highway-mpg" are represented by mpg (miles per gallon) unit. Assume we are developing an application in a country that accept the fuel consumption with L/100km standard</p>
# <p>We will need to apply <b>data transformation</b> to transform mpg into L/100km?</p>

# %% [markdown]
# <p>The formula for unit conversion is<p>
# L/100km = 235 / mpg
# <p>We can do many mathematical operations directly in Pandas.</p>

# %% [markdown]
# <h2 id="data_normalization">Data Normalization</h2>
#
# <b>Why normalization?</b>
# <p>Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1
# </p>
#
# <b>Example</b>
# <p>To demonstrate normalization, let's say we want to scale the columns "length", "width" and "height" </p>
# <p><b>Target:</b>would like to Normalize those variables so their value ranges from 0 to 1.</p>
# <p><b>Approach:</b> replace original value by (original value)/(maximum value)</p>

# %%
# replace (original value) by (original value)/(maximum value)
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %%
df['height'] = df['height']/df['height'].max() 
# show the scaled columns
df[["length","width","height"]].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.822681  0.909722  0.876254
# 2  0.848630  0.919444  0.908027
# 3  0.848630  0.922222  0.908027
# 4  0.851994  0.920833  0.887960

# %% [markdown]
# #### Binning

# %% [markdown]
# <p>Binning during data analysis comes in handy in several cases.One good example is when there is a need to present graphical representation of data and it dosen't really give so much information when plotted as a continous variable so we then use bins to convert that continous variable into a categorical varialbe.In other words we are grouping this continous variables into specific ranges.</p>

# %% [markdown]
# <p> The horse power column in our dataset will provide a good example to show how binning can be effective</p>

# %%
#.unique gives us the distinct values in a column
c=df.horsepower.unique()

# %%
horse_unique_values=pd.Series(c)

# %%
horse_unique_values.count()
# Out:
# 59

# %%
print(df['horsepower'].astype(int).min())
print(df['horsepower'].astype(int).max())
# Out:
# 48
# 262

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %% [markdown]
# <p> Let's make a plot of the horsepower column to get its frequency count</p>

# %%
import matplotlib.pyplot as plt

# %%
df.horsepower.plot(kind='hist')
plt.xlabel('Values')
# Out:
# Text(0.5, 0, 'Values')

# %% [markdown]
# </p> Well the above viz is good but then it appears choked up. What if we just want to categorize the data into 3 categories that is <b>high</b>, <b>medium</b> and <b>low</b>. This is where binning becomes useful it allows us to categorize this data values

# %% [markdown]
# <p>We would like 3 bins of equal size bandwidth so we use numpy's <code>linspace(start_value, end_value, numbers_generated</code> function.</p>
# <p>Since we want to include the minimum value of horsepower we want to set start_value=min(df["horsepower"]).</p>
# <p>Since we want to include the maximum value of horsepower we want to set end_value=max(df["horsepower"]).</p>
# <p>Since we are building 3 bins of equal length, there should be 4 dividers, so numbers_generated=4.</p>

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %% [markdown]
#  We apply the function "cut" the determine what each value of "df['horsepower']" belongs to.

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          154            Medium
# 2          102               Low
# 3          115               Low
# 4          110               Low
# 5          110               Low
# 6          110               Low
# 7          140            Medium
# 8          101               Low
# 9          101               Low
# 10         121            Medium
# 11         121            Medium
# 12         121            Medium
# 13         182            Medium
# 14         182            Medium
# 15         182            Medium
# 16          48               Low
# 17          70               Low
# 18          70               Low
# 19          68               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       152
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


a = (0,1,2)

# draw historgram of attribute "horsepower" with bins = 3
#plt.pyplot.hist(df["horsepower"], bins = 3)

# set x/y labels and plot title
#plt.pyplot.xlabel("horsepower")
#plt.pyplot.ylabel("count")
#plt.pyplot.title("horsepower bins")
df['horsepower'].plot(kind='hist',bins=3)
plt.xlabel('horsepower')
plt.ylabel('count')
plt.title('horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# <p> Another use case where bining comes in handy is when creating models for machine learning sometimes we might just have only a single feature in a large dataset and when using a linear regression model there is no substantial representation of the features. We can create bins for the values in the dataset and group them in to specific ranges then using the <b>np.digitize</b> method from numpy to give us the bin where each data value falls in. Then we could apply one hot encoding on the result and then train our models on it.</p>  <p> I will delve into this in another notebook</p>

# %% [markdown]
# <h2> Dummy Variables</h2>
# <p>These gives the same results as <b>one hot encoding</b> but they only work on categorical variables

# %% [markdown]
# <h2> Dummy Variables</h2>
# <p>These gives the same results as <b>one hot encoding</b> but they only work on categorical variables

# %% [markdown]
# <h2 id="indicator">Indicator variable (or dummy variable)</h2>
# <b>What is an indicator variable?</b>
# <p>
#     An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning. In pandas dummy variables give the same results just like when you use one hot encoding but they only work on categorical variable
# </p>
#
# <b>Why we use indicator variables?</b>
# <p>
#     So we can use categorical variables for regression analysis in the later modules.
# </p>
# <b>Example</b>
# <p>
#     We see the column "fuel-type" has two unique values, "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.
# </p>
#
# <p>
#     We will use the panda's method 'get_dummies' to assign numerical values to different categories of fuel type.
# </p>

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("fuel-type", axis = 1, inplace=True)

# %%
df
#The fuel_type column has been removed.
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            1                122  alfa-romero        std          two
# 2            2                164         audi        std         four
# 3            2                164         audi        std         four
# 4            2                122         audi        std          two
# ..         ...                ...          ...        ...          ...
# 195         -1                 95        volvo        std         four
# 196         -1                 95        volvo      turbo         four
# 197         -1                 95        volvo        std         four
# 198         -1                 95        volvo      turbo         four
# 199         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %% [markdown]
# <p> There is one more column that needs to be converted into numerical variables like above. You can find it and perform the neccessary conversions</p>

# %% [markdown]
# <p> Thanks for completing this notebook</p>
#
# <a href=https://www.linkedin.com/in/adediwura/>connect with me on Linkedin</a>
